# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/input/cifar-10/python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# CIFAR-10 Dataset: 171MB [02:36, 1.09MB/s]
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 5
sample_id = 6447
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 5:
# Samples: 10000
# Label Counts: {0: 1014, 1: 1014, 2: 952, 3: 1016, 4: 997, 5: 1025, 6: 980, 7: 977, 8: 1003, 9: 1022}
# First 20 Labels: [1, 8, 5, 1, 5, 7, 4, 3, 8, 2, 7, 2, 0, 1, 5, 9, 6, 2, 0, 8]
#
# Example of Image 6447:
# Image - Min Value: 0 Max Value: 228
# Image - Shape: (32, 32, 3)
# Label - Label Id: 6 Name: frog

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    x = (255.0-x)/255.0;
    return x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    
    z = list()    
    for label in x:
        temp = np.zeros(10)
        temp[label] = 1
        z.append(temp)
    return np.array(z)
    


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    placeholder = tf.placeholder(tf.float32,shape=(None,image_shape[0],image_shape[1],image_shape[2]),name="x")
    return placeholder


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    placeholder = tf.placeholder(tf.int32,shape=(None,n_classes),name="y")
    return placeholder


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    placeholder = tf.placeholder(tf.float32,name="keep_prob")
    return placeholder


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    # print(x_tensor)
    
    in_channels=int(x_tensor.shape[-1])
    
    weight = tf.Variable(tf.truncated_normal((conv_ksize[0],conv_ksize[1],in_channels,conv_num_outputs)),name = "weight")
    bias = tf.Variable(tf.zeros(conv_num_outputs), name = "bias")
    
    conv_action = tf.nn.conv2d(x_tensor,weight,[1,conv_strides[0],conv_strides[0],1,],'SAME')
    relu_action = tf.nn.relu(tf.nn.bias_add(conv_action,bias))
  
    output_val = tf.nn.max_pool(relu_action,[1,pool_ksize[0],pool_ksize[1],1],[1,pool_strides[0],pool_strides[1],1],'SAME')    
    
    return output_val 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    flattened_arr = tf.contrib.layers.flatten(x_tensor) 
    return flattened_arr


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    output = tf.contrib.layers.fully_connected(inputs=x_tensor,num_outputs=num_outputs)
    return output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    output = tf.contrib.layers.fully_connected(inputs=x_tensor,num_outputs=num_outputs,activation_fn=None)
    return output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    x1=conv2d_maxpool(x, 60, (6,6), (2,2), (4,4), (2,2))
    x1= tf.nn.dropout(x1,keep_prob)
    x2=conv2d_maxpool(x1, 40, (5,5), (2,2), (4,4), (2,2))
    x2= tf.nn.dropout(x2,keep_prob)
    x3=conv2d_maxpool(x2, 30, (3,3), (2,2), (2,2), (2,2))
    x3= tf.nn.dropout(x3,keep_prob)
    

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    x_flattened = flatten(x3)
    

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    y1= fully_conn(x_flattened, 40)
    y1= tf.nn.dropout(y1,keep_prob)
    y2= fully_conn(y1, 35)
    y2= tf.nn.dropout(y2,keep_prob)
    y3= fully_conn(y2, 30)
    
    
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    fin_output = output(y3, 10)
    
    
    # TODO: return output
    return fin_output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    session.run(optimizer,feed_dict={x:feature_batch,y:label_batch,keep_prob:keep_probability})
    


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    acc = session.run(accuracy,feed_dict={x: feature_batch, y: label_batch, keep_prob: 1.0})
    print('accuracy %g' % (acc*100.0))
    cost_ = session.run(cost,feed_dict={x: feature_batch, y: label_batch, keep_prob: 1.0})
    print('cost %g' % (cost_))
    #print(accuracy.eval(feed_dict={x: feature_batch, y_: label_batch, keep_prob: 1.0}))
    #print(cost.eval(feed_dict={x: feature_batch, y_: label_batch, keep_prob: 1.0}))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 70
batch_size = 256
keep_probability = 0.4

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  accuracy 7.5
# cost 14.5719
# Epoch  2, CIFAR-10 Batch 1:  accuracy 5
# cost 5.03543
# Epoch  3, CIFAR-10 Batch 1:  accuracy 2.5
# cost 3.9878
# Epoch  4, CIFAR-10 Batch 1:  accuracy 5
# cost 3.02977
# Epoch  5, CIFAR-10 Batch 1:  accuracy 7.5
# cost 2.64005
# Epoch  6, CIFAR-10 Batch 1:  accuracy 7.5
# cost 2.61437
# Epoch  7, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.50997
# Epoch  8, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.47276
# Epoch  9, CIFAR-10 Batch 1:  accuracy 10
# cost 2.41725
# Epoch 10, CIFAR-10 Batch 1:  accuracy 7.5
# cost 2.38504
# Epoch 11, CIFAR-10 Batch 1:  accuracy 5
# cost 2.37422
# Epoch 12, CIFAR-10 Batch 1:  accuracy 5
# cost 2.35988
# Epoch 13, CIFAR-10 Batch 1:  accuracy 2.5
# cost 2.35956
# Epoch 14, CIFAR-10 Batch 1:  accuracy 2.5
# cost 2.34779
# Epoch 15, CIFAR-10 Batch 1:  accuracy 0
# cost 2.33291
# Epoch 16, CIFAR-10 Batch 1:  accuracy 7.5
# cost 2.3271
# Epoch 17, CIFAR-10 Batch 1:  accuracy 2.5
# cost 2.32893
# Epoch 18, CIFAR-10 Batch 1:  accuracy 5
# cost 2.32916
# Epoch 19, CIFAR-10 Batch 1:  accuracy 5
# cost 2.33136
# Epoch 20, CIFAR-10 Batch 1:  accuracy 5
# cost 2.32485
# Epoch 21, CIFAR-10 Batch 1:  accuracy 5
# cost 2.32436
# Epoch 22, CIFAR-10 Batch 1:  accuracy 5
# cost 2.31911
# Epoch 23, CIFAR-10 Batch 1:  accuracy 5
# cost 2.31873
# Epoch 24, CIFAR-10 Batch 1:  accuracy 5
# cost 2.31689
# Epoch 25, CIFAR-10 Batch 1:  accuracy 7.5
# cost 2.31203
# Epoch 26, CIFAR-10 Batch 1:  accuracy 7.5
# cost 2.31071
# Epoch 27, CIFAR-10 Batch 1:  accuracy 10
# cost 2.30539
# Epoch 28, CIFAR-10 Batch 1:  accuracy 10
# cost 2.3025
# Epoch 29, CIFAR-10 Batch 1:  accuracy 10
# cost 2.30107
# Epoch 30, CIFAR-10 Batch 1:  accuracy 10
# cost 2.29938
# Epoch 31, CIFAR-10 Batch 1:  accuracy 10
# cost 2.29942
# Epoch 32, CIFAR-10 Batch 1:  accuracy 10
# cost 2.29816
# Epoch 33, CIFAR-10 Batch 1:  accuracy 10
# cost 2.29824
# Epoch 34, CIFAR-10 Batch 1:  accuracy 10
# cost 2.29839
# Epoch 35, CIFAR-10 Batch 1:  accuracy 10
# cost 2.29818
# Epoch 36, CIFAR-10 Batch 1:  accuracy 10
# cost 2.29842
# Epoch 37, CIFAR-10 Batch 1:  accuracy 10
# cost 2.29963
# Epoch 38, CIFAR-10 Batch 1:  accuracy 10
# cost 2.29928
# Epoch 39, CIFAR-10 Batch 1:  accuracy 10
# cost 2.29908
# Epoch 40, CIFAR-10 Batch 1:  accuracy 10
# cost 2.29914
# Epoch 41, CIFAR-10 Batch 1:  accuracy 10
# cost 2.29953
# Epoch 42, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.29983
# Epoch 43, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30106
# Epoch 44, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.301
# Epoch 45, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30123
# Epoch 46, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30125
# Epoch 47, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30145
# Epoch 48, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30145
# Epoch 49, CIFAR-10 Batch 1:  accuracy 10
# cost 2.30144
# Epoch 50, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30162
# Epoch 51, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30165
# Epoch 52, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.3018
# Epoch 53, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.3018
# Epoch 54, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30195
# Epoch 55, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.3019
# Epoch 56, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30193
# Epoch 57, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30214
# Epoch 58, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30214
# Epoch 59, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.3021
# Epoch 60, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30219
# Epoch 61, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30209
# Epoch 62, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30209
# Epoch 63, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30191
# Epoch 64, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30165
# Epoch 65, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30142
# Epoch 66, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30147
# Epoch 67, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.3016
# Epoch 68, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.3015
# Epoch 69, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30149
# Epoch 70, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30168

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  accuracy 5
# cost 37.0564
# Epoch  1, CIFAR-10 Batch 2:  accuracy 10
# cost 15.1093
# Epoch  1, CIFAR-10 Batch 3:  accuracy 15
# cost 9.37926
# Epoch  1, CIFAR-10 Batch 4:  accuracy 2.5
# cost 5.3891
# Epoch  1, CIFAR-10 Batch 5:  accuracy 10
# cost 3.9856
# Epoch  2, CIFAR-10 Batch 1:  accuracy 7.5
# cost 3.01629
# Epoch  2, CIFAR-10 Batch 2:  accuracy 7.5
# cost 2.51382
# Epoch  2, CIFAR-10 Batch 3:  accuracy 10
# cost 2.53618
# Epoch  2, CIFAR-10 Batch 4:  accuracy 5
# cost 2.34902
# Epoch  2, CIFAR-10 Batch 5:  accuracy 7.5
# cost 2.35051
# Epoch  3, CIFAR-10 Batch 1:  accuracy 7.5
# cost 2.39129
# Epoch  3, CIFAR-10 Batch 2:  accuracy 5
# cost 2.3054
# Epoch  3, CIFAR-10 Batch 3:  accuracy 5
# cost 2.29927
# Epoch  3, CIFAR-10 Batch 4:  accuracy 7.5
# cost 2.30535
# Epoch  3, CIFAR-10 Batch 5:  accuracy 15
# cost 2.30844
# Epoch  4, CIFAR-10 Batch 1:  accuracy 7.5
# cost 2.35342
# Epoch  4, CIFAR-10 Batch 2:  accuracy 5
# cost 2.29821
# Epoch  4, CIFAR-10 Batch 3:  accuracy 7.5
# cost 2.29986
# Epoch  4, CIFAR-10 Batch 4:  accuracy 10
# cost 2.29731
# Epoch  4, CIFAR-10 Batch 5:  accuracy 12.5
# cost 2.31559
# Epoch  5, CIFAR-10 Batch 1:  accuracy 10
# cost 2.34768
# Epoch  5, CIFAR-10 Batch 2:  accuracy 5
# cost 2.29909
# Epoch  5, CIFAR-10 Batch 3:  accuracy 7.5
# cost 2.29648
# Epoch  5, CIFAR-10 Batch 4:  accuracy 10
# cost 2.29368
# Epoch  5, CIFAR-10 Batch 5:  accuracy 12.5
# cost 2.31174
# Epoch  6, CIFAR-10 Batch 1:  accuracy 10
# cost 2.34066
# Epoch  6, CIFAR-10 Batch 2:  accuracy 5
# cost 2.29693
# Epoch  6, CIFAR-10 Batch 3:  accuracy 7.5
# cost 2.29391
# Epoch  6, CIFAR-10 Batch 4:  accuracy 10
# cost 2.29219
# Epoch  6, CIFAR-10 Batch 5:  accuracy 12.5
# cost 2.30722
# Epoch  7, CIFAR-10 Batch 1:  accuracy 10
# cost 2.33255
# Epoch  7, CIFAR-10 Batch 2:  accuracy 5
# cost 2.29555
# Epoch  7, CIFAR-10 Batch 3:  accuracy 7.5
# cost 2.29279
# Epoch  7, CIFAR-10 Batch 4:  accuracy 10
# cost 2.29076
# Epoch  7, CIFAR-10 Batch 5:  accuracy 12.5
# cost 2.30464
# Epoch  8, CIFAR-10 Batch 1:  accuracy 10
# cost 2.32557
# Epoch  8, CIFAR-10 Batch 2:  accuracy 5
# cost 2.29437
# Epoch  8, CIFAR-10 Batch 3:  accuracy 15
# cost 2.29219
# Epoch  8, CIFAR-10 Batch 4:  accuracy 7.5
# cost 2.29172
# Epoch  8, CIFAR-10 Batch 5:  accuracy 10
# cost 2.30264
# Epoch  9, CIFAR-10 Batch 1:  accuracy 7.5
# cost 2.3183
# Epoch  9, CIFAR-10 Batch 2:  accuracy 17.5
# cost 2.29437
# Epoch  9, CIFAR-10 Batch 3:  accuracy 15
# cost 2.29336
# Epoch  9, CIFAR-10 Batch 4:  accuracy 7.5
# cost 2.2942
# Epoch  9, CIFAR-10 Batch 5:  accuracy 10
# cost 2.30111
# Epoch 10, CIFAR-10 Batch 1:  accuracy 7.5
# cost 2.31429
# Epoch 10, CIFAR-10 Batch 2:  accuracy 17.5
# cost 2.29563
# Epoch 10, CIFAR-10 Batch 3:  accuracy 15
# cost 2.29484
# Epoch 10, CIFAR-10 Batch 4:  accuracy 7.5
# cost 2.29579
# Epoch 10, CIFAR-10 Batch 5:  accuracy 10
# cost 2.30031
# Epoch 11, CIFAR-10 Batch 1:  accuracy 7.5
# cost 2.31157
# Epoch 11, CIFAR-10 Batch 2:  accuracy 17.5
# cost 2.29666
# Epoch 11, CIFAR-10 Batch 3:  accuracy 15
# cost 2.2963
# Epoch 11, CIFAR-10 Batch 4:  accuracy 7.5
# cost 2.29655
# Epoch 11, CIFAR-10 Batch 5:  accuracy 10
# cost 2.30017
# Epoch 12, CIFAR-10 Batch 1:  accuracy 7.5
# cost 2.30943
# Epoch 12, CIFAR-10 Batch 2:  accuracy 17.5
# cost 2.29751
# Epoch 12, CIFAR-10 Batch 3:  accuracy 15
# cost 2.29694
# Epoch 12, CIFAR-10 Batch 4:  accuracy 7.5
# cost 2.29713
# Epoch 12, CIFAR-10 Batch 5:  accuracy 10
# cost 2.30017
# Epoch 13, CIFAR-10 Batch 1:  accuracy 7.5
# cost 2.30773
# Epoch 13, CIFAR-10 Batch 2:  accuracy 17.5
# cost 2.29842
# Epoch 13, CIFAR-10 Batch 3:  accuracy 15
# cost 2.29779
# Epoch 13, CIFAR-10 Batch 4:  accuracy 7.5
# cost 2.29821
# Epoch 13, CIFAR-10 Batch 5:  accuracy 12.5
# cost 2.30052
# Epoch 14, CIFAR-10 Batch 1:  accuracy 10
# cost 2.30603
# Epoch 14, CIFAR-10 Batch 2:  accuracy 17.5
# cost 2.29953
# Epoch 14, CIFAR-10 Batch 3:  accuracy 15
# cost 2.29897
# Epoch 14, CIFAR-10 Batch 4:  accuracy 7.5
# cost 2.2992
# Epoch 14, CIFAR-10 Batch 5:  accuracy 12.5
# cost 2.30038
# Epoch 15, CIFAR-10 Batch 1:  accuracy 10
# cost 2.30581
# Epoch 15, CIFAR-10 Batch 2:  accuracy 17.5
# cost 2.3002
# Epoch 15, CIFAR-10 Batch 3:  accuracy 15
# cost 2.29958
# Epoch 15, CIFAR-10 Batch 4:  accuracy 7.5
# cost 2.30012
# Epoch 15, CIFAR-10 Batch 5:  accuracy 12.5
# cost 2.30068
# Epoch 16, CIFAR-10 Batch 1:  accuracy 10
# cost 2.30521
# Epoch 16, CIFAR-10 Batch 2:  accuracy 17.5
# cost 2.29983
# Epoch 16, CIFAR-10 Batch 3:  accuracy 15
# cost 2.29917
# Epoch 16, CIFAR-10 Batch 4:  accuracy 7.5
# cost 2.30059
# Epoch 16, CIFAR-10 Batch 5:  accuracy 12.5
# cost 2.301
# Epoch 17, CIFAR-10 Batch 1:  accuracy 10
# cost 2.30461
# Epoch 17, CIFAR-10 Batch 2:  accuracy 5
# cost 2.30025
# Epoch 17, CIFAR-10 Batch 3:  accuracy 15
# cost 2.29932
# Epoch 17, CIFAR-10 Batch 4:  accuracy 12.5
# cost 2.30115
# Epoch 17, CIFAR-10 Batch 5:  accuracy 12.5
# cost 2.30091
# Epoch 18, CIFAR-10 Batch 1:  accuracy 10
# cost 2.30423
# Epoch 18, CIFAR-10 Batch 2:  accuracy 5
# cost 2.30085
# Epoch 18, CIFAR-10 Batch 3:  accuracy 15
# cost 2.29952
# Epoch 18, CIFAR-10 Batch 4:  accuracy 12.5
# cost 2.3009
# Epoch 18, CIFAR-10 Batch 5:  accuracy 10
# cost 2.30109
# Epoch 19, CIFAR-10 Batch 1:  accuracy 10
# cost 2.3038
# Epoch 19, CIFAR-10 Batch 2:  accuracy 5
# cost 2.30096
# Epoch 19, CIFAR-10 Batch 3:  accuracy 15
# cost 2.29989
# Epoch 19, CIFAR-10 Batch 4:  accuracy 12.5
# cost 2.30097
# Epoch 19, CIFAR-10 Batch 5:  accuracy 10
# cost 2.3015
# Epoch 20, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30336
# Epoch 20, CIFAR-10 Batch 2:  accuracy 17.5
# cost 2.30055
# Epoch 20, CIFAR-10 Batch 3:  accuracy 15
# cost 2.29912
# Epoch 20, CIFAR-10 Batch 4:  accuracy 12.5
# cost 2.3014
# Epoch 20, CIFAR-10 Batch 5:  accuracy 10
# cost 2.30173
# Epoch 21, CIFAR-10 Batch 1:  accuracy 7.5
# cost 2.30325
# Epoch 21, CIFAR-10 Batch 2:  accuracy 17.5
# cost 2.3005
# Epoch 21, CIFAR-10 Batch 3:  accuracy 15
# cost 2.29912
# Epoch 21, CIFAR-10 Batch 4:  accuracy 12.5
# cost 2.30112
# Epoch 21, CIFAR-10 Batch 5:  accuracy 10
# cost 2.30187
# Epoch 22, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30301
# Epoch 22, CIFAR-10 Batch 2:  accuracy 17.5
# cost 2.30037
# Epoch 22, CIFAR-10 Batch 3:  accuracy 15
# cost 2.29905
# Epoch 22, CIFAR-10 Batch 4:  accuracy 12.5
# cost 2.30135
# Epoch 22, CIFAR-10 Batch 5:  accuracy 10
# cost 2.30189
# Epoch 23, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30305
# Epoch 23, CIFAR-10 Batch 2:  accuracy 17.5
# cost 2.30062
# Epoch 23, CIFAR-10 Batch 3:  accuracy 15
# cost 2.29918
# Epoch 23, CIFAR-10 Batch 4:  accuracy 12.5
# cost 2.30133
# Epoch 23, CIFAR-10 Batch 5:  accuracy 10
# cost 2.30195
# Epoch 24, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30294
# Epoch 24, CIFAR-10 Batch 2:  accuracy 17.5
# cost 2.30029
# Epoch 24, CIFAR-10 Batch 3:  accuracy 15
# cost 2.29915
# Epoch 24, CIFAR-10 Batch 4:  accuracy 12.5
# cost 2.30137
# Epoch 24, CIFAR-10 Batch 5:  accuracy 10
# cost 2.30213
# Epoch 25, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30277
# Epoch 25, CIFAR-10 Batch 2:  accuracy 17.5
# cost 2.30053
# Epoch 25, CIFAR-10 Batch 3:  accuracy 15
# cost 2.29954
# Epoch 25, CIFAR-10 Batch 4:  accuracy 12.5
# cost 2.30107
# Epoch 25, CIFAR-10 Batch 5:  accuracy 10
# cost 2.30214
# Epoch 26, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30282
# Epoch 26, CIFAR-10 Batch 2:  accuracy 17.5
# cost 2.30099
# Epoch 26, CIFAR-10 Batch 3:  accuracy 15
# cost 2.29952
# Epoch 26, CIFAR-10 Batch 4:  accuracy 12.5
# cost 2.30118
# Epoch 26, CIFAR-10 Batch 5:  accuracy 10
# cost 2.30186
# Epoch 27, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30284
# Epoch 27, CIFAR-10 Batch 2:  accuracy 17.5
# cost 2.3013
# Epoch 27, CIFAR-10 Batch 3:  accuracy 20
# cost 2.29975
# Epoch 27, CIFAR-10 Batch 4:  accuracy 12.5
# cost 2.30102
# Epoch 27, CIFAR-10 Batch 5:  accuracy 10
# cost 2.30167
# Epoch 28, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30289
# Epoch 28, CIFAR-10 Batch 2:  accuracy 5
# cost 2.30094
# Epoch 28, CIFAR-10 Batch 3:  accuracy 20
# cost 2.29962
# Epoch 28, CIFAR-10 Batch 4:  accuracy 12.5
# cost 2.30073
# Epoch 28, CIFAR-10 Batch 5:  accuracy 10
# cost 2.30178
# Epoch 29, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30286
# Epoch 29, CIFAR-10 Batch 2:  accuracy 17.5
# cost 2.3013
# Epoch 29, CIFAR-10 Batch 3:  accuracy 20
# cost 2.3
# Epoch 29, CIFAR-10 Batch 4:  accuracy 12.5
# cost 2.30065
# Epoch 29, CIFAR-10 Batch 5:  accuracy 10
# cost 2.30179
# Epoch 30, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30287
# Epoch 30, CIFAR-10 Batch 2:  accuracy 17.5
# cost 2.30118
# Epoch 30, CIFAR-10 Batch 3:  accuracy 20
# cost 2.29979
# Epoch 30, CIFAR-10 Batch 4:  accuracy 12.5
# cost 2.30057
# Epoch 30, CIFAR-10 Batch 5:  accuracy 10
# cost 2.30188
# Epoch 31, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30284
# Epoch 31, CIFAR-10 Batch 2:  accuracy 17.5
# cost 2.30118
# Epoch 31, CIFAR-10 Batch 3:  accuracy 20
# cost 2.29974
# Epoch 31, CIFAR-10 Batch 4:  accuracy 12.5
# cost 2.30078
# Epoch 31, CIFAR-10 Batch 5:  accuracy 10
# cost 2.3018
# Epoch 32, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30306
# Epoch 32, CIFAR-10 Batch 2:  accuracy 17.5
# cost 2.3012
# Epoch 32, CIFAR-10 Batch 3:  accuracy 20
# cost 2.29994
# Epoch 32, CIFAR-10 Batch 4:  accuracy 12.5
# cost 2.30079
# Epoch 32, CIFAR-10 Batch 5:  accuracy 10
# cost 2.30183
# Epoch 33, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30309
# Epoch 33, CIFAR-10 Batch 2:  accuracy 17.5
# cost 2.30114
# Epoch 33, CIFAR-10 Batch 3:  accuracy 20
# cost 2.29993
# Epoch 33, CIFAR-10 Batch 4:  accuracy 12.5
# cost 2.30082
# Epoch 33, CIFAR-10 Batch 5:  accuracy 10
# cost 2.3018
# Epoch 34, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.303
# Epoch 34, CIFAR-10 Batch 2:  accuracy 17.5
# cost 2.30118
# Epoch 34, CIFAR-10 Batch 3:  accuracy 20
# cost 2.29989
# Epoch 34, CIFAR-10 Batch 4:  accuracy 12.5
# cost 2.30076
# Epoch 34, CIFAR-10 Batch 5:  accuracy 10
# cost 2.30192
# Epoch 35, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30295
# Epoch 35, CIFAR-10 Batch 2:  accuracy 17.5
# cost 2.30135
# Epoch 35, CIFAR-10 Batch 3:  accuracy 20
# cost 2.29995
# Epoch 35, CIFAR-10 Batch 4:  accuracy 12.5
# cost 2.30095
# Epoch 35, CIFAR-10 Batch 5:  accuracy 10
# cost 2.30194
# Epoch 36, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30288
# Epoch 36, CIFAR-10 Batch 2:  accuracy 17.5
# cost 2.30104
# Epoch 36, CIFAR-10 Batch 3:  accuracy 20
# cost 2.29963
# Epoch 36, CIFAR-10 Batch 4:  accuracy 12.5
# cost 2.30082
# Epoch 36, CIFAR-10 Batch 5:  accuracy 10
# cost 2.30214
# Epoch 37, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30271
# Epoch 37, CIFAR-10 Batch 2:  accuracy 17.5
# cost 2.30092
# Epoch 37, CIFAR-10 Batch 3:  accuracy 20
# cost 2.29962
# Epoch 37, CIFAR-10 Batch 4:  accuracy 12.5
# cost 2.30082
# Epoch 37, CIFAR-10 Batch 5:  accuracy 10
# cost 2.30215
# Epoch 38, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.3027
# Epoch 38, CIFAR-10 Batch 2:  accuracy 17.5
# cost 2.30109
# Epoch 38, CIFAR-10 Batch 3:  accuracy 20
# cost 2.29985
# Epoch 38, CIFAR-10 Batch 4:  accuracy 12.5
# cost 2.30085
# Epoch 38, CIFAR-10 Batch 5:  accuracy 10
# cost 2.30227
# Epoch 39, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30274
# Epoch 39, CIFAR-10 Batch 2:  accuracy 17.5
# cost 2.30115
# Epoch 39, CIFAR-10 Batch 3:  accuracy 20
# cost 2.30009
# Epoch 39, CIFAR-10 Batch 4:  accuracy 12.5
# cost 2.30097
# Epoch 39, CIFAR-10 Batch 5:  accuracy 10
# cost 2.30217
# Epoch 40, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30279
# Epoch 40, CIFAR-10 Batch 2:  accuracy 17.5
# cost 2.30118
# Epoch 40, CIFAR-10 Batch 3:  accuracy 20
# cost 2.29993
# Epoch 40, CIFAR-10 Batch 4:  accuracy 12.5
# cost 2.30085
# Epoch 40, CIFAR-10 Batch 5:  accuracy 10
# cost 2.30211
# Epoch 41, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30285
# Epoch 41, CIFAR-10 Batch 2:  accuracy 17.5
# cost 2.30109
# Epoch 41, CIFAR-10 Batch 3:  accuracy 20
# cost 2.29992
# Epoch 41, CIFAR-10 Batch 4:  accuracy 12.5
# cost 2.30072
# Epoch 41, CIFAR-10 Batch 5:  accuracy 10
# cost 2.30214
# Epoch 42, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30284
# Epoch 42, CIFAR-10 Batch 2:  accuracy 17.5
# cost 2.30117
# Epoch 42, CIFAR-10 Batch 3:  accuracy 20
# cost 2.29996
# Epoch 42, CIFAR-10 Batch 4:  accuracy 12.5
# cost 2.30052
# Epoch 42, CIFAR-10 Batch 5:  accuracy 10
# cost 2.30219
# Epoch 43, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30275
# Epoch 43, CIFAR-10 Batch 2:  accuracy 17.5
# cost 2.30104
# Epoch 43, CIFAR-10 Batch 3:  accuracy 20
# cost 2.29975
# Epoch 43, CIFAR-10 Batch 4:  accuracy 12.5
# cost 2.30053
# Epoch 43, CIFAR-10 Batch 5:  accuracy 10
# cost 2.30227
# Epoch 44, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30275
# Epoch 44, CIFAR-10 Batch 2:  accuracy 17.5
# cost 2.30103
# Epoch 44, CIFAR-10 Batch 3:  accuracy 20
# cost 2.29982
# Epoch 44, CIFAR-10 Batch 4:  accuracy 12.5
# cost 2.30077
# Epoch 44, CIFAR-10 Batch 5:  accuracy 10
# cost 2.30231
# Epoch 45, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30282
# Epoch 45, CIFAR-10 Batch 2:  accuracy 17.5
# cost 2.30137
# Epoch 45, CIFAR-10 Batch 3:  accuracy 20
# cost 2.30012
# Epoch 45, CIFAR-10 Batch 4:  accuracy 12.5
# cost 2.30077
# Epoch 45, CIFAR-10 Batch 5:  accuracy 10
# cost 2.30223
# Epoch 46, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30285
# Epoch 46, CIFAR-10 Batch 2:  accuracy 17.5
# cost 2.30125
# Epoch 46, CIFAR-10 Batch 3:  accuracy 20
# cost 2.29995
# Epoch 46, CIFAR-10 Batch 4:  accuracy 12.5
# cost 2.30081
# Epoch 46, CIFAR-10 Batch 5:  accuracy 10
# cost 2.30232
# Epoch 47, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30283
# Epoch 47, CIFAR-10 Batch 2:  accuracy 17.5
# cost 2.30114
# Epoch 47, CIFAR-10 Batch 3:  accuracy 20
# cost 2.29999
# Epoch 47, CIFAR-10 Batch 4:  accuracy 12.5
# cost 2.3008
# Epoch 47, CIFAR-10 Batch 5:  accuracy 10
# cost 2.30225
# Epoch 48, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30277
# Epoch 48, CIFAR-10 Batch 2:  accuracy 17.5
# cost 2.30135
# Epoch 48, CIFAR-10 Batch 3:  accuracy 20
# cost 2.30015
# Epoch 48, CIFAR-10 Batch 4:  accuracy 12.5
# cost 2.30083
# Epoch 48, CIFAR-10 Batch 5:  accuracy 10
# cost 2.30223
# Epoch 49, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30284
# Epoch 49, CIFAR-10 Batch 2:  accuracy 17.5
# cost 2.30145
# Epoch 49, CIFAR-10 Batch 3:  accuracy 20
# cost 2.3003
# Epoch 49, CIFAR-10 Batch 4:  accuracy 12.5
# cost 2.3009
# Epoch 49, CIFAR-10 Batch 5:  accuracy 10
# cost 2.30222
# Epoch 50, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30283
# Epoch 50, CIFAR-10 Batch 2:  accuracy 17.5
# cost 2.30128
# Epoch 50, CIFAR-10 Batch 3:  accuracy 20
# cost 2.30007
# Epoch 50, CIFAR-10 Batch 4:  accuracy 12.5
# cost 2.301
# Epoch 50, CIFAR-10 Batch 5:  accuracy 10
# cost 2.30226
# Epoch 51, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30278
# Epoch 51, CIFAR-10 Batch 2:  accuracy 17.5
# cost 2.30122
# Epoch 51, CIFAR-10 Batch 3:  accuracy 20
# cost 2.30002
# Epoch 51, CIFAR-10 Batch 4:  accuracy 12.5
# cost 2.30084
# Epoch 51, CIFAR-10 Batch 5:  accuracy 10
# cost 2.30227
# Epoch 52, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30273
# Epoch 52, CIFAR-10 Batch 2:  accuracy 17.5
# cost 2.30125
# Epoch 52, CIFAR-10 Batch 3:  accuracy 20
# cost 2.30011
# Epoch 52, CIFAR-10 Batch 4:  accuracy 12.5
# cost 2.30076
# Epoch 52, CIFAR-10 Batch 5:  accuracy 10
# cost 2.30218
# Epoch 53, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30277
# Epoch 53, CIFAR-10 Batch 2:  accuracy 17.5
# cost 2.30135
# Epoch 53, CIFAR-10 Batch 3:  accuracy 20
# cost 2.30013
# Epoch 53, CIFAR-10 Batch 4:  accuracy 12.5
# cost 2.30078
# Epoch 53, CIFAR-10 Batch 5:  accuracy 10
# cost 2.3022
# Epoch 54, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30278
# Epoch 54, CIFAR-10 Batch 2:  accuracy 17.5
# cost 2.30139
# Epoch 54, CIFAR-10 Batch 3:  accuracy 20
# cost 2.30019
# Epoch 54, CIFAR-10 Batch 4:  accuracy 12.5
# cost 2.30085
# Epoch 54, CIFAR-10 Batch 5:  accuracy 10
# cost 2.30215
# Epoch 55, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30282
# Epoch 55, CIFAR-10 Batch 2:  accuracy 17.5
# cost 2.30148
# Epoch 55, CIFAR-10 Batch 3:  accuracy 20
# cost 2.30013
# Epoch 55, CIFAR-10 Batch 4:  accuracy 12.5
# cost 2.30079
# Epoch 55, CIFAR-10 Batch 5:  accuracy 10
# cost 2.30216
# Epoch 56, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30277
# Epoch 56, CIFAR-10 Batch 2:  accuracy 17.5
# cost 2.30143
# Epoch 56, CIFAR-10 Batch 3:  accuracy 20
# cost 2.30012
# Epoch 56, CIFAR-10 Batch 4:  accuracy 12.5
# cost 2.3008
# Epoch 56, CIFAR-10 Batch 5:  accuracy 10
# cost 2.30223
# Epoch 57, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30272
# Epoch 57, CIFAR-10 Batch 2:  accuracy 17.5
# cost 2.3014
# Epoch 57, CIFAR-10 Batch 3:  accuracy 20
# cost 2.30009
# Epoch 57, CIFAR-10 Batch 4:  accuracy 12.5
# cost 2.30071
# Epoch 57, CIFAR-10 Batch 5:  accuracy 10
# cost 2.30226
# Epoch 58, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30274
# Epoch 58, CIFAR-10 Batch 2:  accuracy 17.5
# cost 2.3014
# Epoch 58, CIFAR-10 Batch 3:  accuracy 20
# cost 2.30006
# Epoch 58, CIFAR-10 Batch 4:  accuracy 12.5
# cost 2.30075
# Epoch 58, CIFAR-10 Batch 5:  accuracy 10
# cost 2.30228
# Epoch 59, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30275
# Epoch 59, CIFAR-10 Batch 2:  accuracy 17.5
# cost 2.30133
# Epoch 59, CIFAR-10 Batch 3:  accuracy 20
# cost 2.30007
# Epoch 59, CIFAR-10 Batch 4:  accuracy 12.5
# cost 2.3008
# Epoch 59, CIFAR-10 Batch 5:  accuracy 10
# cost 2.30225
# Epoch 60, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30273
# Epoch 60, CIFAR-10 Batch 2:  accuracy 17.5
# cost 2.3013
# Epoch 60, CIFAR-10 Batch 3:  accuracy 20
# cost 2.3
# Epoch 60, CIFAR-10 Batch 4:  accuracy 12.5
# cost 2.30076
# Epoch 60, CIFAR-10 Batch 5:  accuracy 10
# cost 2.30223
# Epoch 61, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30272
# Epoch 61, CIFAR-10 Batch 2:  accuracy 17.5
# cost 2.30124
# Epoch 61, CIFAR-10 Batch 3:  accuracy 20
# cost 2.29999
# Epoch 61, CIFAR-10 Batch 4:  accuracy 12.5
# cost 2.3008
# Epoch 61, CIFAR-10 Batch 5:  accuracy 10
# cost 2.30227
# Epoch 62, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30269
# Epoch 62, CIFAR-10 Batch 2:  accuracy 17.5
# cost 2.30125
# Epoch 62, CIFAR-10 Batch 3:  accuracy 20
# cost 2.29995
# Epoch 62, CIFAR-10 Batch 4:  accuracy 12.5
# cost 2.3008
# Epoch 62, CIFAR-10 Batch 5:  accuracy 10
# cost 2.30229
# Epoch 63, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30272
# Epoch 63, CIFAR-10 Batch 2:  accuracy 17.5
# cost 2.30117
# Epoch 63, CIFAR-10 Batch 3:  accuracy 20
# cost 2.29985
# Epoch 63, CIFAR-10 Batch 4:  accuracy 12.5
# cost 2.30076
# Epoch 63, CIFAR-10 Batch 5:  accuracy 10
# cost 2.30225
# Epoch 64, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30273
# Epoch 64, CIFAR-10 Batch 2:  accuracy 17.5
# cost 2.30113
# Epoch 64, CIFAR-10 Batch 3:  accuracy 20
# cost 2.29989
# Epoch 64, CIFAR-10 Batch 4:  accuracy 12.5
# cost 2.30074
# Epoch 64, CIFAR-10 Batch 5:  accuracy 10
# cost 2.30226
# Epoch 65, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30271
# Epoch 65, CIFAR-10 Batch 2:  accuracy 17.5
# cost 2.30117
# Epoch 65, CIFAR-10 Batch 3:  accuracy 20
# cost 2.2999
# Epoch 65, CIFAR-10 Batch 4:  accuracy 12.5
# cost 2.30076
# Epoch 65, CIFAR-10 Batch 5:  accuracy 10
# cost 2.30226
# Epoch 66, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30272
# Epoch 66, CIFAR-10 Batch 2:  accuracy 17.5
# cost 2.30117
# Epoch 66, CIFAR-10 Batch 3:  accuracy 20
# cost 2.29994
# Epoch 66, CIFAR-10 Batch 4:  accuracy 12.5
# cost 2.30073
# Epoch 66, CIFAR-10 Batch 5:  accuracy 10
# cost 2.30229
# Epoch 67, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.3027
# Epoch 67, CIFAR-10 Batch 2:  accuracy 17.5
# cost 2.30125
# Epoch 67, CIFAR-10 Batch 3:  accuracy 20
# cost 2.3
# Epoch 67, CIFAR-10 Batch 4:  accuracy 12.5
# cost 2.30073
# Epoch 67, CIFAR-10 Batch 5:  accuracy 10
# cost 2.30229
# Epoch 68, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30269
# Epoch 68, CIFAR-10 Batch 2:  accuracy 17.5
# cost 2.30123
# Epoch 68, CIFAR-10 Batch 3:  accuracy 20
# cost 2.29999
# Epoch 68, CIFAR-10 Batch 4:  accuracy 12.5
# cost 2.30075
# Epoch 68, CIFAR-10 Batch 5:  accuracy 10
# cost 2.30231
# Epoch 69, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.30268
# Epoch 69, CIFAR-10 Batch 2:  accuracy 17.5
# cost 2.30124
# Epoch 69, CIFAR-10 Batch 3:  accuracy 20
# cost 2.30004
# Epoch 69, CIFAR-10 Batch 4:  accuracy 12.5
# cost 2.30074
# Epoch 69, CIFAR-10 Batch 5:  accuracy 10
# cost 2.30234
# Epoch 70, CIFAR-10 Batch 1:  accuracy 12.5
# cost 2.3027
# Epoch 70, CIFAR-10 Batch 2:  accuracy 17.5
# cost 2.30119
# Epoch 70, CIFAR-10 Batch 3:  accuracy 20
# cost 2.30001
# Epoch 70, CIFAR-10 Batch 4:  accuracy 12.5
# cost 2.30072
# Epoch 70, CIFAR-10 Batch 5:  accuracy 10
# cost 2.30237

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.10205078125

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
